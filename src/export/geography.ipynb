# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

import os
os.chdir("C:/Users/ibrah/OneDrive/Documents/classicmodel-analysis")
from src.database.connection import get_connection


conn = get_connection()
query = """ SELECT country, COUNT(customerNumber) as nb_clients
FROM customers
GROUP BY country; """
df = pd.read_sql(query, conn)

plt.figure()
sns.barplot(data=df, x='country', y='nb_clients')
plt.xticks(rotation=90)
plt.title("Répartition des clients par pays")
plt.tight_layout()
plt.savefig("visualisations/customers_by_country.png")
plt.show()
# Out:
# C:\Users\ibrah\AppData\Local\Temp\ipykernel_21096\2392080027.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
